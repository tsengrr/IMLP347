# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.  線性迴歸訓練資料、測試資料
#
# 80%  training data, 20%  testing data ==> 先利用此來驗證各種模型(演算法)的好壞及調好到最佳參數
# 之後可以利用由這個80%的訓練資料所得的模型後,拿100%資料re-train模型以得到最佳模型 (此model會更佳fit data)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = np.linspace(0, 5, 50)
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
print(x_train)
# Out:
# [4.08163265 1.73469388 1.83673469 0.         2.75510204 3.36734694
#  3.67346939 4.28571429 1.02040816 0.30612245 4.18367347 1.32653061
#  4.69387755 0.20408163 3.87755102 3.97959184 0.51020408 4.3877551
#  3.7755102  3.06122449 0.6122449  2.95918367 1.63265306 1.93877551
#  5.         4.48979592 2.14285714 3.26530612 3.46938776 0.71428571
#  2.24489796 1.12244898 2.04081633 0.91836735 4.89795918 2.85714286
#  3.16326531 1.53061224 2.65306122 3.57142857]

# %%
y
# Out:
# array([ 1.54320268,  2.00522821,  0.72277817, -0.0121231 ,  2.36862652,
#         1.3999813 ,  1.3815046 ,  1.67164906,  1.51302091,  1.67752117,
#         2.21318082,  1.80890498,  1.99206808,  1.39745072,  1.90768668,
#         2.73421488,  3.2392427 ,  1.84928117,  2.36465434,  3.91249683,
#         3.30945294,  3.57701034,  1.77513272,  3.72582403,  4.10723658,
#         4.18860775,  3.84873455,  3.76827672,  5.86092038,  3.8414311 ,
#         4.5272509 ,  4.56658607,  5.02847388,  4.29783654,  3.81339633,
#         4.34708283,  6.24096896,  4.46106264,  4.9446844 ,  5.61045456,
#         7.00642557,  6.03761342,  5.46892704,  6.16492859,  6.61726293,
#         6.19154728,  6.34199459,  6.25922802,  7.50794991,  6.58444518])

# %%
plt.scatter(x_train, y_train)

# %% [markdown]
# #### 用訓練資料來 fit 函數
#
# 記得現在我們只用 80% 的資料去訓練。

# %%
regr = LinearRegression()
X_train = x_train.reshape(-1,1)
regr.fit(X_train,y_train)
print('Coefficients: ', regr.coef_)
print('interception: ', regr.intercept_)
# Out:
# Coefficients:  [1.27162765]
# interception:  0.5209911358792465

# %%
Y_train = regr.predict(X_train)

# %%
mse = np.sum((Y_train-y_train)**2) / len(y_train)
print(mse)
# Out:
# 0.4538142830518552

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, Y_train, 'r')

# %% [markdown]
# #### test with test data

# %%
X_test = x_test.reshape(-1,1)
Y_test = regr.predict(X_test)

print(Y_test)
# Out:
# [2.07808622 2.33760207 1.04002283 1.55905453 6.3600977  0.65074906
#  3.76493923 3.6351813  6.61961355 3.50542338]

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+b$$

# %%
#Y=WX+b
W=regr.coef_
b=regr.intercept_
W*X_test+b
# Out:
# array([[2.07808622],
#        [2.33760207],
#        [1.04002283],
#        [1.55905453],
#        [6.3600977 ],
#        [0.65074906],
#        [3.76493923],
#        [3.6351813 ],
#        [6.61961355],
#        [3.50542338]])

# %%
mse = np.sum((Y_test-y_test)**2) / len(y_test)
print(mse)
# Out:
# 0.44033416022346605

# %%
title='f(x)=1.2x+0.8'+',mse:'+str(round(mse,2))
plt.title(title)
plt.xlabel('x')
plt.ylabel('y')
#plt.grid(True)
plt.scatter(x_test, y_test,alpha=0.8,label='Ground Truth')
plt.scatter(x_test, Y_test, c='r', alpha=0.8,label='Predict')
plt.legend()
